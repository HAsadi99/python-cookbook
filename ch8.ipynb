# %%
# chapter 8 Handling Images

# %%
# Loading Images
import cv2
import numpy as np
from matplotlib import  pyplot as plt

# Load image as grayscale
image = cv2.imread('images.jpeg' , cv2.IMREAD_GRAYSCALE)

# show image
plt.imshow(image, cmap = "gray")
plt.axis('off')
plt.show()

# %%
# show data type
type(image)
# Out:
# numpy.ndarray

# %%
# show image data
image
# Out:
# array([[115, 115, 115, ..., 113, 113, 113],
#        [115, 115, 115, ..., 113, 113, 113],
#        [115, 115, 115, ..., 113, 113, 113],
#        ...,
#        [124, 124, 124, ..., 124, 124, 124],
#        [124, 124, 124, ..., 124, 124, 124],
#        [124, 124, 124, ..., 124, 124, 124]], shape=(183, 275), dtype=uint8)

# %%
# show dimensions
image.shape
# Out:
# (183, 275)

# %%
image[0,0]
# Out:
# np.uint8(115)

# %%
# Load image in color
image_bgr = cv2.imread('images.jpeg' , cv2.IMREAD_COLOR)

# show pixel
image_bgr[0,0]
# Out:
# array([115, 115, 115], dtype=uint8)

# %%
image_bgr.shape
# Out:
# (183, 275, 3)

# %%
plt.imshow(image_bgr)

# %%
# convert to RGB
image_rgb = cv2.cvtColor(image_bgr , cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis('off')
plt.show()

# %%
# 8.2 Saving Images

# oad image as grayscale
image = cv2.imread('images.jpeg', cv2.IMREAD_GRAYSCALE)

# save image
cv2.imwrite('images.jpeg' , image)
# Out:
# True

# %%
# 8.3 Resizing Images

# load image as grayscale
image = cv2.imread('images.jpeg', cv2.IMREAD_GRAYSCALE)

# Resize image to 50 pixels by 50 pixels
image_70_70 = cv2.resize(image , (70, 70))

# view image
plt.imshow(image_70_70 , cmap='gray')
plt.axis('off')
plt.show()

# %%
# 8.4 Cropping Images

image = cv2.imread('images.jpeg' , cv2.IMREAD_GRAYSCALE)

# crop image with select
image_cropped = image[: , :180]

# show image
plt.imshow(image_cropped, cmap = "gray")
plt.axis('off')
plt.show()

# %%
# 8.5 Blurring Images

# load image in gray style
image = cv2.imread('images.jpeg' , cv2.IMREAD_GRAYSCALE)

# blur image
image_blurry = cv2.blur(image, (5,5))

# show image
plt.imshow(image_blurry, cmap = "gray")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
image_very_blurry = cv2.blur(image, (50,50))

# show image
plt.imshow(image_very_blurry, cmap = "gray")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# create kernel
kernel = np.ones((5,5)) / 25

kernel
# Out:
# array([[0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04],
#        [0.04, 0.04, 0.04, 0.04, 0.04]])

# %%
# Apply kernel
image_kernel = cv2.filter2D(image, -1, kernel)

plt.imshow(image_kernel, cmap = "gray")
plt.axis('off')
plt.xticks([])
# Out:
# ([], [])

# %%
# 8.6 Sharpening Images
# load image in gray style
image = cv2.imread('images.jpeg' , cv2.IMREAD_GRAYSCALE)

# create kernel
kernel = np.array([[0, -1, 0],
                   [-1, 5,-1],
                   [0, -1, 0]])

# sharpen image
image_sharp = cv2.filter2D(image, -1, kernel)

# show image
plt.imshow(image_sharp, cmap = "gray")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
import cv2
import numpy as np
from matplotlib import  pyplot as plt

# 8.7 Enhancing Contrast
image = cv2.imread("images.jpeg" , cv2.IMREAD_GRAYSCALE)

image_enhanced = cv2.equalizeHist(image)

plt.imshow(image_enhanced , cmap = "gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# load image
image_bgr = cv2.imread("images1.jpeg")

# convert to YUV
image_yuv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2YUV)

image_yuv[:, :, 0] = cv2.equalizeHist(image_yuv[:, :, 0])

# convert to RGB
image_rgb = cv2.cvtColor(image_yuv, cv2.COLOR_YUV2RGB)

# show image
plt.imshow(image_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# 8.8 Isolating Colors

image_bgr = cv2.imread("images1.jpeg")

# convert BGR to HSV
image_hsv = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2HSV)

# Define range of blue values in HSV
lower_blue = np.array([50,100,50])
upper_blue = np.array([130,255,255])

mask = cv2.inRange(image_hsv, lower_blue, upper_blue)

# mask image
image_bgr_mask = cv2.bitwise_and(image_bgr,image_bgr,mask=mask)

# convert BGR to RGB
image_rgb =cv2.cvtColor(image_bgr_mask, cv2.COLOR_BGR2RGB)

plt.imshow(image_rgb)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# show image
plt.imshow(mask, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# 8.9 Binarizing Images
import cv2
import numpy as np
from matplotlib import pyplot as plt

# load image as gray style
image_gray = cv2.imread("images.jpeg" , cv2.IMREAD_GRAYSCALE)

# apply adaptive thresholding
max_output_value = 255
neighborhood_size = 99
subtract_from_mean = 10
image_binarized = cv2.adaptiveThreshold(image_gray ,
                                        max_output_value,
                                        cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                        cv2.THRESH_BINARY,
                                        neighborhood_size,
                                        subtract_from_mean)

plt.imshow(image_binarized, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# Apply cv2.ADAPTIVE_THRESH_MEAN_C
image_mean_threshold = cv2.adaptiveThreshold(image_gray,
                                             max_output_value,
                                             cv2.ADAPTIVE_THRESH_MEAN_C,
                                             cv2.THRESH_BINARY,
                                             neighborhood_size,
                                             subtract_from_mean)

plt.imshow(image_mean_threshold , cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# 8.10 Removing Backgrounds
import cv2
import numpy as np
from matplotlib import pyplot as plt

# loaf image and convert to RGB
image_bgr = cv2.imread("images1.jpeg" )
image_rgb = cv2.cvtColor(image_bgr,cv2.COLOR_BGR2RGB)

# Rectangle values: start x, start y, width, height
rectangle = (0, 80, 256, 150)

# create initial mask
mask = np.zeros(image_rgb.shape[:2], np.uint8)

# Create temporary arrays used by grabCut
bgdModel = np.zeros((1, 65), np.float64)
fgdModel= np.zeros((1, 65), np.float64)

# run grabCut
cv2.grabCut(image_rgb,
            mask,
            rectangle,
            bgdModel,              # temporary array for background
            fgdModel,
            5,                     # number of iteration
            cv2.GC_INIT_WITH_RECT) # initiative using our rectangle

# Create mask where sure and likely backgrounds set to 0, otherwise 1
mask_2 = np.where((mask ==2) | (mask==0) ,0 , 1).astype('uint8')

# Multiplying image withe new mask to subtract background
image_rgb_nobg = image_rgb * mask_2[:, :, np.newaxis]

plt.imshow(image_rgb_nobg)

# %%
# Show mask
plt.imshow(mask, cmap='gray')
plt.show()
plt.imshow(mask_2 , cmap='gray')

# %%
# 8.11 Detecting Edges

# load image as grayscale
image_gray = cv2.imread("images.jpeg" , cv2.IMREAD_GRAYSCALE)

# calculate median intensity
median_intensity = np.median(image_gray)

# set thresholds to be one standard deviation above and below median intensity
lower_threshold = int(max(0, (1.0 - 0.33) * median_intensity))
upper_threshold = int(min(255, (1.0 + 0.33) * median_intensity))

# apply canny edge detector
image_canny = cv2.Canny(image_gray, lower_threshold, upper_threshold)

# show image
plt.imshow(image_canny, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
# 8.12 Detecting Corners

image_bgr = cv2.imread("images1.jpeg")
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)
image_gray = np.float32(image_gray)

# Set corner detector parameters
block_size = 2
aperture = 29
free_parameter = 0.04

# Detect corners
detector_responses = cv2.cornerHarris(image_gray, 
                                      block_size,
                                      aperture,
                                      free_parameter)

# Large corner markers
detector_responses = cv2.dilate(detector_responses , None)

# only keep detector responses greater than threshold , mark as white
threshold = 0.02
image_bgr[detector_responses > threshold * detector_responses.max()] = [255, 255, 255]

# convert to grayscale
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# show image
plt.imshow(image_gray, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(274.5), np.float64(182.5), np.float64(-0.5))

# %%
plt.imshow(detector_responses, cmap='gray')
plt.show()

# %%
image_bgr = cv2.imread('images.jpeg')
image_gray = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

# number of corners to detect
corners_to_detect = 10
minimum_quality_score = 0.05
minimum_distance = 25

# Detect corners
corners = cv2.goodFeaturesToTrack(image_gray,
                                  corners_to_detect,
                                  minimum_quality_score,
                                  minimum_distance)

corners = np.int16(corners)

# Draw white circle at each corner
for corner in corners:
    x, y = corner[0]
    cv2.circle(image_bgr, (x,y), 7 , (255,255,255), 2)
    

# convert to grayscale
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2GRAY)

plt.imshow(image_rgb, cmap="gray")
# plt.axis("off")

# %%
corners.shape
# Out:
# (10, 1, 2)

# %%
# 8.13 Creating Features for Machine Learning
import cv2
import numpy as np
from matplotlib import pyplot as plt

# load image as grayscale
image = cv2.imread("images.jpeg" , cv2.IMREAD_GRAYSCALE)

# resize image to 10 pixel by 10 pixel
image_10_10 = cv2.resize(image, (10,10))

# convert image data to one dimensional vector
image_10_10.flatten()
# Out:
# array([116, 117, 118, 119, 119, 119, 118, 118, 117, 116, 117, 118, 119,
#        120, 121, 121, 121, 120, 118, 117, 118, 119, 121, 122, 122, 122,
#        122, 121, 120, 118, 118, 121, 123, 124, 124, 124, 123, 122, 121,
#        119, 120, 123, 128, 126, 126, 126, 125, 124, 122, 121, 121,  94,
#        212, 213, 123,  45, 126, 126, 131, 122, 122, 125, 124,  80,  46,
#        248, 244,  76, 169, 122, 124, 125, 126,  84, 111,  92, 106, 221,
#        213, 124, 124, 125, 126, 128, 128, 128, 127, 127, 125, 124, 124,
#        126, 127, 128, 128, 128, 128, 127, 125, 124], dtype=uint8)

# %%
plt.imshow(image_10_10, cmap="gray")
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(9.5), np.float64(9.5), np.float64(-0.5))

# %%
image_10_10.shape
# Out:
# (10, 10)

# %%
image_10_10.flatten().shape
# Out:
# (100,)

# %%
# Load image in color
image_color = cv2.imread("images1.jpeg", cv2.IMREAD_COLOR)

# resize image to 10 pixel by 10 pixel
image_color_10_10 = cv2.resize(image_color, (10,10))

# convert image data to one dimensional vector, show dimension
image_color_10_10.flatten().shape
# Out:
# (300,)

# %%
# load image in grayscale
image_256x256_gray = cv2.imread("images.jpeg" , cv2.IMREAD_GRAYSCALE)

# Convert image data to one-dimensional vector
image_256x256_gray.flatten().shape
# Out:
# (50325,)

# %%
# load image
image_256x256_color = cv2.imread("images1.jpeg" , cv2.IMREAD_COLOR)

# Convert image data to one-dimensional vector
image_256x256_color.flatten().shape
# Out:
# (150975,)

# %%
# 8.14 Encoding Color Histograms as Features
import cv2
import numpy as np
from matplotlib import pyplot as plt

np.random.seed(0)

# load image
image_bgr = cv2.imread("images1.jpeg", cv2.IMREAD_COLOR)

# convert to rgb
image_rgb = cv2.cvtColor(image_bgr , cv2.COLOR_BGR2RGB)

# create a list for features
features = []

# Calculate the histogram for each color channel
colors = ("r", "g", "b")

# For each channel: calculate histogram and add to feature value list
for i,channel in enumerate(colors):
    histogram = cv2.calcHist([image_rgb],  # image
                        [i],                 # index of channel;
                        None,              # no mask
                        [256],            # histogram size
                        [0,256])           # range
    features.extend(histogram)
    
# Create a vector for an observation's feature values
observation = np.array(features).flatten()

# show the observation's value for the first five features
observation[0:5]
# Out:
# array([106.,  10.,  16.,  14.,   7.], dtype=float32)

# %%
# show RGB channel values
image_rgb[0,0]
# Out:
# array([ 65, 124, 200], dtype=uint8)

# %%
# import pandas
import pandas as pd

# create some data
data = pd.Series([1, 1, 2, 2, 3, 3, 3, 4, 5])

# show the histogram
data.hist(grid=False)
plt.show()

# %%
# Calculate the histogram for each color channel
colors = ("r", "g", "b")

# For each channel: calculate histogram, make plot
for i,channel in enumerate(colors):
    histogram = cv2.calcHist([image_rgb],
                             [i],
                             None,
                             [256],
                             [0,256])
    plt.plot(histogram, color = channel)
    plt.xlim([0,256])

# %%
# 8.15 Using Pretrained Embeddings as Features
import cv2
import numpy as np
import torch
from torchvision import transforms
import torchvision.models as models

# load image
image_bgr = cv2.imread("images1.jpeg", cv2.IMREAD_COLOR)

# Convert to pytorch data type
convert_tensor = transforms.ToTensor()
pytorch_image = convert_tensor(np.array(image_bgr))

# Load the pretrained model
model = models.resnet18(pretrained =True)

# Select the specific layer of the model we want output from
layer = model._modules.get('avgpool')

# set model to evaluation mode
model.eval()

# Infer the embedding with teh no grad option
with torch.no_grad():
    embedding = model(pytorch_image.unsqueeze(0))
    

print(embedding.shape)
# Out:
# torch.Size([1, 1000])

# %%
# Load libraries
import cv2
import tensorflow as tf
import tensorflow_hub as hub

image_bgr = cv2.imread("images1.jpeg", cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# convert to tensorflow data type
tf_image =tf.image.convert_image_dtype([image_rgb], tf.float32)

# create the model and get embedding using the inception v1 model
embedding_model = hub.KerasLayer(
    "https://tfhub.dev/google/imagenet/inception_v1/feature_vector/5"
)

embeddings = embedding_model(tf_image)

# print the shape pf the embedding
print(embeddings.shape)
# Out:
# 2025-08-14 01:37:36.604079: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755122856.843441   17536 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1755122856.910082   17536 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1755122857.317992   17536 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# 8.16 Detecting Objects with OpenCV
# Import libraries
import cv2
from matplotlib import pyplot as plt

face_cascade = cv2.CascadeClassifier()
face_cascade.load(
    cv2.samples.findFile(
        "haarcascade_frontalface_default.xml"
    )
)

# Load image
image_bgr = cv2.imread("face.jpg", cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# Detect faces and draw rectangle
faces = face_cascade.detectMultiScale(image_rgb)
for (x,y,w,h) in faces:
    cv2.rectangle(image_rgb, (x, y),
                  (x + h, y + w),
                  (0, 255, 0), 5)
    
# show the image
plt.subplot(1, 1, 1)
plt.imshow(image_rgb)
plt.show()

# %%
# 8.17 Classifying Images with Pytorch
import json
from torchvision import transforms
from torchvision.models import resnet18
import urllib.request

# get imagenet classes
with urllib.request.urlopen(
    "https://raw.githubusercontent.com/raghakot/keras-vis/master/resources/imagenet_class_index.json"
    ) as url:
    imagenet_class_index = json.load(url)

    
# Instantiate pretrained model
model = resnet18(pretrained = True)

image_bgr = cv2.imread("images1.jpeg", cv2.IMREAD_COLOR)
image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)

# convert to pytorch data type
convert_tensor = transforms.ToTensor()
pytorch_image = convert_tensor(np.array(image_rgb))

# set model to evaluation mode
model.eval()

# make prediction
prediction = model(pytorch_image.unsqueeze(0))

# Get the index of the highest predicted probability
_, index = torch.max(prediction, 1)

# convert that to a percentage value
percentage = torch.nn.functional.softmax(prediction, dim=1)[0] * 100

# print the name of the item at the index along with the percent confidence
print(imagenet_class_index[str(index.tolist()[0])][1],
      percentage[index.tolist()[0]].item())
# Out:
# /home/hadisasadi/myenv310/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/hadisasadi/myenv310/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# airliner 57.524959564208984
